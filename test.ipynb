# %%
import pyarrow.parquet as pq

# Đọc file parquet
dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\mcc (1).parquet")

# Đọc toàn bộ thành bảng Arrow
table = dataset.read()  # <-- thay vì to_pandas()

# Chuyển sang pandas DataFrame
df = table.to_pandas()

# %%
df
# Out:
#         _operation               _processed_at    _record_id _source_database  \
# 0     INITIAL_LOAD  2025-10-15T02:44:51.831796   MDI_mcc_565              MDI
# 1     INITIAL_LOAD  2025-10-15T02:44:51.836199     MDI_mcc_1              MDI
# 2     INITIAL_LOAD  2025-10-15T02:44:51.838477     MDI_mcc_2              MDI
# 3     INITIAL_LOAD  2025-10-15T02:44:51.840916     MDI_mcc_3              MDI
# 4     INITIAL_LOAD  2025-10-15T02:44:51.842941     MDI_mcc_4              MDI
# ...            ...                         ...           ...              ...
# 997   INITIAL_LOAD  2025-10-15T02:44:53.644491   MDI_mcc_998              MDI
# 998   INITIAL_LOAD  2025-10-15T02:44:53.646103   MDI_mcc_999              MDI
# 999   INITIAL_LOAD  2025-10-15T02:44:53.648117  MDI_mcc_1000              MDI
# 1000        INSERT  2025-10-15T02:47:07.656726  MDI_mcc_1001              MDI
# 1001        INSERT  2025-10-15T02:47:07.838004  MDI_mcc_1002              MDI
#
#      _source_table _source_type      bs_xe  diem_don_ghi_chu      diem_tra  \
# 0              mcc   postgresql  51K-22323     Cổng trường A  Ga Long Biên
# 1              mcc   postgresql  75M-59996       Cổng hẻm 12  Khu đô thị Z
# 2              mcc   postgresql  74U-30089       Khách sạn X         KCN A
# 3              mcc   postgresql  42T-24872        Cổng chợ C  Khu đô thị Z
# 4              mcc   postgresql  86L-26680        Cổng chợ C         Chợ N
# ...            ...          ...        ...               ...           ...
# 997            mcc   postgresql  22F-62461       Khách sạn X  Ga Long Biên
# 998            mcc   postgresql  93R-12047   Sân bay Nội Bài   Bệnh viện T
# 999            mcc   postgresql  65D-81360   Bến xe Giáp Bát         Chợ N
# 1000           mcc   postgresql  30A-99999    Bến xe Mỹ Đình      Cầu Giấy
# 1001           mcc   postgresql  29B-56789  Bến xe Nước Ngầm       Hà Đông
#
#       don_vi_phat_sinh     ma_nv ngay_di_thuc_te ngay_hieu_luc  \
# 0         Đội Vận hành    NV2905      2024-07-08    2024-11-07
# 1        Phòng Dịch vụ    NV7125      2024-07-08    2024-08-19
# 2     Công ty TNHH XYZ    NV9969      2024-07-08    2024-04-28
# 3       Đơn vị Đối tác    NV2372      2024-07-08    2024-06-24
# 4         Đội Vận hành    NV2094      2024-07-08    2024-02-08
# ...                ...       ...             ...           ...
# 997        Công ty ABC    NV7889      2024-07-08    2024-10-11
# 998   Công ty TNHH XYZ    NV7470      2024-07-08    2024-12-28
# 999   Công ty TNHH XYZ    NV2185      2024-07-08    2024-08-23
# 1000  Công ty Test MCC  NVTEST02      2025-10-12    2025-10-20
# 1001  Công ty Test MCC  NVTEST03      2025-10-13    2025-10-25
#
#              san_pham so_giao_dich            so_the     so_tien   stt  \
# 0              SIM 4G            9  2798246481747051  1542297.18   565
# 1          Gói Cước B            5  6378892119264243  1891258.54     1
# 2          Gói Cước A            8  8637939391594387  1992874.38     2
# 3              SIM 4G            4  2248883920193645   826977.61     3
# 4      Thẻ Vận Chuyển            7  1990609089540616   137600.66     4
# ...               ...          ...               ...         ...   ...
# 997        Gói Cước A            6  6101444449758513   361921.17   998
# 998            SIM 4G            5  7112095902717879   905395.38   999
# 999        Gói Cước A            4  7278183732502073   294534.29  1000
# 1000  Gói Cước Test A            2          12112003    300000.0  1001
# 1001  Gói Cước Test B            3  5555444433332222    450000.0  1002
#
#       ten_in_tren_the
# 0         Lê Thị Oanh
# 1     Huỳnh Thị Quỳnh
# 2      Hoàng Minh Đức
# 3        Lưu Văn Phúc
# 4         Vũ Thị Hồng
# ...               ...
# 997    Trịnh Thúy Nga
# 998      Lưu Văn Phúc
# 999       Mai Thị Yến
# 1000   LÊ THỊ KIM YẾN
# 1001       VƯƠNG BÌNH
#
# [1002 rows x 19 columns]
