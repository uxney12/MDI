# %%
import pyarrow.parquet as pq

dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\part-00000-da365e66-fd43-4617-8e52-145257e21980-c000.snappy.parquet")
table = dataset.read() 
df = table.to_pandas()

# %%
import pandas as pd

# %%
df
# Out:
#    STT  Mã KH  Mã HĐ Mã nhân viên NV quản lý Mã lái xe ID cuốc xe  \
# 0    1   None   None        NV001       None      None       None
# 1    2   None   None       nv-002       None      None       None
# 2    3   None   None        NV003       None      None       None
# 3    4   None   None        nv004       None      None       None
# 4    5   None   None       NV_005       None      None       None
# 5    6   None   None        nv006       None      None       None
# 6    7   None   None        NV007       None      None       None
# 7    8   None   None        nv008       None      None       None
# 8    9   None   None        nv009       None      None       None
# 9   10   None   None        NV010       None      None       None
# 10   1  KH001  HD001         None      NV001     LX001      CX001
# 11   2  KH002  HD002         None     nv-002     LX002      CX002
# 12   3  KH003  HD003         None      NV003     LX003      CX003
# 13   4  KH004  HD004         None      nv004     LX004      CX004
# 14   5  KH005  HD005         None     NV_005     LX005      CX005
# 15   6  KH006  HD006         None      nv006     LX006      CX006
# 16   7  KH007  HD007         None      NV007     LX007      CX007
# 17   8  KH008  HD008         None      nv008     LX008      CX008
# 18   9  KH009  HD009         None      nv009     LX009      CX009
# 19  10  KH010  HD010         None      NV010     LX010      CX010
#
#               Số thẻ  Tên trên thẻ  Sản phẩm  ...  Điểm đón      Điểm trả  \
# 0   7278183732502073  NGUYEN VAN A  FuelCard  ...  Cầu Giấy  Hai Bà Trưng
# 1   7278183732502074    Trần thị b   XangA95  ...    Ha Noi     Long Bien
# 2   7278183732502075      LÊ VĂN C    Dầu DO  ...        Q1            Q7
# 3               2076      le thi d    xangE5  ...  Bac Ninh            HN
# 4   7278183732502077    Pham Van E      fuel  ...   Cty ABC       Cty XYZ
# 5   7278183732502078      NG VAN F      xang  ...   Đống Đa      Cầu Giấy
# 6   7278183732502079    Tran Van G       A92  ...      QL1A            HN
# 7               2080      LÊ tHỊ h    Diesel  ...    Diem A        Diem B
# 8   7278183732502081    PHAM VAN i  E5-RON92  ...       HCM    Bình Dương
# 9   7278183732502082      Nguyen J        DO  ...        DN            QN
# 10  7278183732502073  NGUYEN VAN A  FuelCard  ...      None          None
# 11  7278183732502074    Tr?n th? b   XangA95  ...      None          None
# 12  7278183732502075      LÊ VAN C    D?u DO  ...      None          None
# 13              2076      le thi d    xangE5  ...      None          None
# 14  7278183732502077    Pham Van E      fuel  ...      None          None
# 15  7278183732502078      NG VAN F      xang  ...      None          None
# 16  7278183732502079    Tran Van G       A92  ...      None          None
# 17              2080      LÊ tH? h    Diesel  ...      None          None
# 18  7278183732502081    PHAM VAN i  E5-RON92  ...      None          None
# 19  7278183732502082      Nguyen J        DO  ...      None          None
#
#    Đơn vị phát sinh Mã ĐV phát sinh Tên ĐV phát sinh Mã ĐV quản lý KH  \
# 0        Petrolimex            None             None             None
# 1            PV OIL            None             None             None
# 2      Saigon Petro            None             None             None
# 3             PVOIL            None             None             None
# 4              PTSC            None             None             None
# 5        Petrolimex            None             None             None
# 6    Công ty TNHH X            None             None             None
# 7            PV OIL            None             None             None
# 8        Petrolimex            None             None             None
# 9        PETROLIMEX            None             None             None
# 10             None           DV001       Petrolimex             None
# 11             None           DV002           PV OIL             None
# 12             None           DV003     Saigon Petro             None
# 13             None           DV004            PVOIL             None
# 14             None           DV005             PTSC             None
# 15             None           DV006       Petrolimex             None
# 16             None           DV007   Công ty TNHH X             None
# 17             None           DV008           PV OIL             None
# 18             None           DV009       Petrolimex             None
# 19             None           DV010       PETROLIMEX             None
#
#    Tên ĐV quản lý KH Trạng thái giao dịch Loại giao dịch Ghi chú
# 0               None                 None           None    None
# 1               None                 None           None    None
# 2               None                 None           None    None
# 3               None                 None           None    None
# 4               None                 None           None    None
# 5               None                 None           None    None
# 6               None                 None           None    None
# 7               None                 None           None    None
# 8               None                 None           None    None
# 9               None                 None           None    None
# 10              None            Ho?t d?ng            N?p    None
# 11              None                 xong            Rút    None
# 12              None                   OK            N?p    None
# 13              None                 done     Thanh toán    None
# 14              None                   ok            Rút    None
# 15              None           Hoàn thành            N?p    None
# 16              None                 None            N?p    None
# 17              None                    x     Thanh toán    None
# 18              None                 None            N?p    None
# 19              None                   ok            Rút    None
#
# [20 rows x 29 columns]
