# %%
import pyarrow.parquet as pq

# Đọc file parquet
dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\part-00000-e68f174e-3cc2-48c6-934e-046b3bb7a1cb-c000.snappy.parquet")

# Đọc toàn bộ thành bảng Arrow
table = dataset.read()  # <-- thay vì to_pandas()

# Chuyển sang pandas DataFrame
df = table.to_pandas()

# %%
df
# Out:
#        STT   Mã KH   Mã HĐ    NV quản lý Mã nhân viên Mã lái xe ID cuốc xe  \
# 0      565    None    None        NV2905         None      None       None
# 1        1    None    None        NV7125         None      None       None
# 2        2    None    None        NV9969         None      None       None
# 3        3    None    None        NV2372         None      None       None
# 4        4    None    None        NV2094         None      None       None
# ...    ...     ...     ...           ...          ...       ...        ...
# 1995   996  KH0367  HD7371   Hoàng Th? F         None    LX0291   CX111266
# 1996   997  KH7439  HD7422     Vu Ng?c G         None    LX4991   CX281890
# 1997   998  KH4550  HD9487  Phan Thanh H         None    LX3111   CX867694
# 1998   999  KH8927  HD0642     Ngô Ð?c I         None    LX3638   CX236422
# 1999  1000  KH7795  HD5918     Bùi Th? J         None    LX1093   CX542430
#
# ...
