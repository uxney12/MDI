# %%
import pyarrow.parquet as pq

# Đọc file parquet
dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\bangke_data.parquet")

# Đọc toàn bộ thành bảng Arrow
table = dataset.read()  # <-- thay vì to_pandas()

# Chuyển sang pandas DataFrame
df = table.to_pandas()

# %%
df
# Out:
#               id source_table     operation                processed_at   stt  \
# 0        MPASS_1        MPASS  INITIAL_LOAD  2025-10-10T09:23:59.559126     1
# 1        MPASS_2        MPASS  INITIAL_LOAD  2025-10-10T09:23:59.588908     2
# 2        MPASS_3        MPASS  INITIAL_LOAD  2025-10-10T09:23:59.634577     3
# 3        MPASS_4        MPASS  INITIAL_LOAD  2025-10-10T09:23:59.660717     4
# 4        MPASS_5        MPASS  INITIAL_LOAD  2025-10-10T09:23:59.692347     5
# ...          ...          ...           ...                         ...   ...
# 1996     MCC_997          MCC  INITIAL_LOAD  2025-10-10T09:26:19.500202   997
# 1997     MCC_998          MCC  INITIAL_LOAD  2025-10-10T09:26:19.676272   998
# 1998     MCC_999          MCC  INITIAL_LOAD  2025-10-10T09:26:19.742798   999
# 1999    MCC_1000          MCC  INITIAL_LOAD  2025-10-10T09:26:19.816753  1000
# 2000  MPASS_1001        MPASS        UPDATE  2025-10-10T09:34:07.877658  1001
#
#          ma_kh     ma_hd       nv_quan_ly ma_nhan_vien ma_lai_xe  ...  \
# 0       KH2269    HD5199      Phạm Hồng D                 LX1948  ...
# 1       KH4722    HD6732         Đỗ Văn E                 LX2723  ...
# 2       KH0771    HD7302        Bùi Thị J                 LX3950  ...
# 3       KH0536    HD0418     Nguyễn Văn A                 LX1698  ...
# 4       KH5360    HD7394       Trần Thị B                 LX0998  ...
# ...        ...       ...              ...          ...       ...  ...
# 1996                                            NV7235            ...
# 1997                                            NV7889            ...
# 1998                                            NV7470            ...
# 1999                                            NV2185            ...
# 2000  KHTEST01  HDTEST01  Nguyễn Văn Test                 LX9999  ...
#
#           diem_tra  don_vi_phat_sinh ma_dv_phat_sinh    ten_dv_phat_sinh  \
# 0                                             DV3744     Phòng KD Hà Nội
# 1                                             DV4484    Công ty TNHH XYZ
# 2                                             DV0860        Phòng KD HCM
# 3                                             DV2963  Chi nhánh Miền Nam
# 4                                             DV1140    Đối tác Liên kết
# ...            ...               ...             ...                 ...
# 1996  Khu đô thị Z    Đơn vị Đối tác
# 1997  Ga Long Biên       Công ty ABC
# 1998   Bệnh viện T  Công ty TNHH XYZ
# 1999         Chợ N  Công ty TNHH XYZ
# 2000                                        DVTEST01      Công ty Test 1
#
#      ma_dv_quan_ly_kh ten_dv_quan_ly_kh trang_thai_giao_dich loai_giao_dich  \
# 0                                                 Đang xử lý     Điều chỉnh
# 1                                                  Hoàn tiền       Nạp tiền
# 2                                                 Đang xử lý       Nạp tiền
# 3                                                   Thất bại       Nạp tiền
# 4                                                  Hoàn tiền     Thanh toán
# ...               ...               ...                  ...            ...
# 1996
# 1997
# 1998
# 1999
# 2000                                              Thành công       Nạp tiền
#
#      ghi_chu is_deleted
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...      ...        ...
# 1996              False
# 1997              False
# 1998              False
# 1999              False
# 2000               True
#
# [2001 rows x 34 columns]
