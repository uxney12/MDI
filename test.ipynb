# %%
import pyarrow.parquet as pq

dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\mcc (3).parquet")
table = dataset.read() 
df = table.to_pandas()

# %%
df
# Out:
#        _operation               _processed_at    _record_id _source_database  \
# 0    INITIAL_LOAD  2025-10-22T02:38:30.532742   MDI_mcc_565              MDI
# 1    INITIAL_LOAD  2025-10-22T02:38:30.538666     MDI_mcc_1              MDI
# 2    INITIAL_LOAD  2025-10-22T02:38:30.541529     MDI_mcc_2              MDI
# 3    INITIAL_LOAD  2025-10-22T02:38:30.543968     MDI_mcc_3              MDI
# 4    INITIAL_LOAD  2025-10-22T02:38:30.546283     MDI_mcc_4              MDI
# ..            ...                         ...           ...              ...
# 995  INITIAL_LOAD  2025-10-22T02:38:32.211031   MDI_mcc_996              MDI
# 996  INITIAL_LOAD  2025-10-22T02:38:32.212358   MDI_mcc_997              MDI
# 997  INITIAL_LOAD  2025-10-22T02:38:32.213653   MDI_mcc_998              MDI
# 998  INITIAL_LOAD  2025-10-22T02:38:32.215069   MDI_mcc_999              MDI
# 999  INITIAL_LOAD  2025-10-22T02:38:32.216372  MDI_mcc_1000              MDI
#
# ...

# %%
# Cách 1: dùng .shape
num_rows = df_filtered.shape[0]

# Cách 2: dùng len()
num_rows = len(df_filtered)

print("Số dòng:", num_rows)
# Out:
# Số dòng: 1002
