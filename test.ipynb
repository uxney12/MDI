# %%
import pyarrow.parquet as pq

# Đọc file parquet
dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\mcc (6).parquet")

# Đọc toàn bộ thành bảng Arrow
table = dataset.read()  # <-- thay vì to_pandas()

# Chuyển sang pandas DataFrame
df = table.to_pandas()

# %%
df
# Out:
#         _operation               _processed_at    _record_id _source_database  \
# 0     INITIAL_LOAD  2025-10-21T07:28:23.981721   MDI_mcc_565              MDI
# 1     INITIAL_LOAD  2025-10-21T07:28:23.990123     MDI_mcc_1              MDI
# 2     INITIAL_LOAD  2025-10-21T07:28:23.993474     MDI_mcc_2              MDI
# 3     INITIAL_LOAD  2025-10-21T07:28:23.997035     MDI_mcc_3              MDI
# 4     INITIAL_LOAD  2025-10-21T07:28:24.000678     MDI_mcc_4              MDI
# ...            ...                         ...           ...              ...
# 996   INITIAL_LOAD  2025-10-21T07:28:25.571676   MDI_mcc_997              MDI
# 997   INITIAL_LOAD  2025-10-21T07:28:25.572880   MDI_mcc_998              MDI
# 998   INITIAL_LOAD  2025-10-21T07:28:25.574138   MDI_mcc_999              MDI
# 999   INITIAL_LOAD  2025-10-21T07:28:25.575548  MDI_mcc_1000              MDI
# 1000        DELETE  2025-10-21T07:29:24.972742  MDI_mcc_1001              MDI
#
#      _source_table _source_type      bs_xe deleted diem_don_ghi_chu  \
# 0              mcc   postgresql  51K-22323   False    Cổng trường A
# 1              mcc   postgresql  75M-59996   False      Cổng hẻm 12
# 2              mcc   postgresql  74U-30089   False      Khách sạn X
# 3              mcc   postgresql  42T-24872   False       Cổng chợ C
# 4              mcc   postgresql  86L-26680   False       Cổng chợ C
# ...            ...          ...        ...     ...              ...
# 996            mcc   postgresql  39Z-18483   False      Trạm dừng D
# 997            mcc   postgresql  22F-62461   False      Khách sạn X
# 998            mcc   postgresql  93R-12047   False  Sân bay Nội Bài
# 999            mcc   postgresql  65D-81360   False  Bến xe Giáp Bát
# 1000           mcc   postgresql  30A-99999    True   Bến xe Mỹ Đình
#
#           diem_tra  ...     ma_nv ngay_di_thuc_te ngay_hieu_luc  \
# 0     Ga Long Biên  ...    NV2905      2024-07-08    2024-11-07
# 1     Khu đô thị Z  ...    NV7125      2024-07-08    2024-08-19
# 2            KCN A  ...    NV9969      2024-07-08    2024-04-28
# 3     Khu đô thị Z  ...    NV2372      2024-07-08    2024-06-24
# 4            Chợ N  ...    NV2094      2024-07-08    2024-02-08
# ...            ...  ...       ...             ...           ...
# 996   Khu đô thị Z  ...    NV7235      2024-07-08    2024-01-31
# 997   Ga Long Biên  ...    NV7889      2024-07-08    2024-10-11
# 998    Bệnh viện T  ...    NV7470      2024-07-08    2024-12-28
# 999          Chợ N  ...    NV2185      2024-07-08    2024-08-23
# 1000      Cầu Giấy  ...  NVTEST02      2025-10-12    2025-10-20
#
#              san_pham so_giao_dich            so_the     so_tien   stt  \
# 0              SIM 4G            9  2798246481747051  1542297.18   565
# 1          Gói Cước B            5  6378892119264243  1891258.54     1
# 2          Gói Cước A            8  8637939391594387  1992874.38     2
# 3              SIM 4G            4  2248883920193645   826977.61     3
# 4      Thẻ Vận Chuyển            7  1990609089540616   137600.66     4
# ...               ...          ...               ...         ...   ...
# 996        Gói Cước B            7  6876000486509870  1884120.23   997
# 997        Gói Cước A            6  6101444449758513   361921.17   998
# 998            SIM 4G            5  7112095902717879   905395.38   999
# 999        Gói Cước A            4  7278183732502073   294534.29  1000
# 1000  Gói Cước Test A            2          12112003   300000.00  1001
#
#       ten_in_tren_the test
# 0         Lê Thị Oanh
# 1     Huỳnh Thị Quỳnh
# 2      Hoàng Minh Đức
# 3        Lưu Văn Phúc
# 4         Vũ Thị Hồng
# ...               ...  ...
# 996       Vũ Thị Hồng
# 997    Trịnh Thúy Nga
# 998      Lưu Văn Phúc
# 999       Mai Thị Yến
# 1000       SEONGHYEON
#
# [1001 rows x 21 columns]

# %%
# Cách 1: dùng .shape
num_rows = df_filtered.shape[0]

# Cách 2: dùng len()
num_rows = len(df_filtered)

print("Số dòng:", num_rows)
# Out:
# Số dòng: 1002
