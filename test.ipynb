# %%
import pyarrow.parquet as pq

# Đọc file parquet
dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\mpass_data.parquet")

# Đọc toàn bộ thành bảng Arrow
table = dataset.read()  # <-- thay vì to_pandas()

# Chuyển sang pandas DataFrame
df = table.to_pandas()

# %%
df
# Out:
#        _operation               _processed_at        _record_id  \
# 0    INITIAL_LOAD  2025-10-13T07:32:24.895040     Mpass_mpass_1
# 1    INITIAL_LOAD  2025-10-13T07:32:24.939391     Mpass_mpass_2
# 2    INITIAL_LOAD  2025-10-13T07:32:24.988311     Mpass_mpass_3
# 3    INITIAL_LOAD  2025-10-13T07:32:25.015343     Mpass_mpass_4
# 4    INITIAL_LOAD  2025-10-13T07:32:25.042454     Mpass_mpass_5
# ..            ...                         ...               ...
# 995  INITIAL_LOAD  2025-10-13T07:32:58.860500   Mpass_mpass_996
# 996  INITIAL_LOAD  2025-10-13T07:32:58.897973   Mpass_mpass_997
# 997  INITIAL_LOAD  2025-10-13T07:32:58.934557   Mpass_mpass_998
# 998  INITIAL_LOAD  2025-10-13T07:32:58.972509   Mpass_mpass_999
# 999  INITIAL_LOAD  2025-10-13T07:32:59.013979  Mpass_mpass_1000
#
#     _source_database _source_table _source_type id_cuoc_xe     loai_gd  \
# 0              Mpass         mpass        mssql   CX671724    N?p ti?n
# 1              Mpass         mpass        mssql   CX658331    N?p ti?n
# 2              Mpass         mpass        mssql   CX937876    N?p ti?n
# 3              Mpass         mpass        mssql   CX132627    N?p ti?n
# 4              Mpass         mpass        mssql   CX220609    N?p ti?n
# ..               ...           ...          ...        ...         ...
# 995            Mpass         mpass        mssql   CX111266  Thanh toán
# 996            Mpass         mpass        mssql   CX281890  Thanh toán
# 997            Mpass         mpass        mssql   CX867694  Thanh toán
# 998            Mpass         mpass        mssql   CX236422  Thanh toán
# 999            Mpass         mpass        mssql   CX542430  Thanh toán
#
#     ma_dv_phat_sinh_gd     ma_gd  ...    nv_quan_ly   san_pham  so_tai  \
# 0               DV3235  GD041366  ...  Nguy?n Van A  Th? Mpass  T32703
# 1               DV3875  GD054541  ...    Tr?n Th? B  Th? Mpass  T60492
# 2               DV0777  GD257098  ...     Lê Minh C  Th? Mpass  T85424
# 3               DV1901  GD753645  ...   Ph?m H?ng D  Th? Mpass  T34223
# 4               DV1112  GD197525  ...      Ð? Van E  Th? Mpass  T08232
# ..                 ...       ...  ...           ...        ...     ...
# 995             DV1685  GD782378  ...   Hoàng Th? F    Th? ETC  T78005
# 996             DV3934  GD138858  ...     Vu Ng?c G    Th? ETC  T59727
# 997             DV1377  GD951307  ...  Phan Thanh H    Th? ETC  T29201
# 998             DV4143  GD128619  ...     Ngô Ð?c I    Th? ETC  T79110
# 999             DV4830  GD689571  ...     Bùi Th? J    Th? ETC  T87370
#
#                so_the     so_tien   stt  ten_dv_phat_sinh_gd ten_in_tren_the  \
# 0    0000001075645715  2036901.42     1  Công ty V?n t?i ABC   Nguy?n Van An
# 1    0000001759404043  1734438.14     2  Công ty V?n t?i ABC   Nguy?n Van An
# 2    0000002085681599  2642044.67     3  Công ty V?n t?i ABC   Nguy?n Van An
# 3    0000000534113992  4138408.48     4  Công ty V?n t?i ABC   Nguy?n Van An
# 4    0000000274647772  4034300.48     5  Công ty V?n t?i ABC   Nguy?n Van An
# ..                ...         ...   ...                  ...             ...
# 995  0000002051908342  4559813.25   996     Ð?i tác Liên k?t   Nguy?n Van An
# 996  0000000681362433  3815628.38   997     Ð?i tác Liên k?t   Nguy?n Van An
# 997  0000001124606443  3100309.99   998     Ð?i tác Liên k?t   Nguy?n Van An
# 998  0000001918964104  4199850.09   999     Ð?i tác Liên k?t   Nguy?n Van An
# 999  0000000061233708  1321605.89  1000     Ð?i tác Liên k?t   Nguy?n Van An
#
#      thoi_diem_giao_dich  trang_thai
# 0    2025-12-27 17:39:17  Thành công
# 1    2025-05-24 07:37:09  Thành công
# 2    2025-10-06 14:07:19  Thành công
# 3    2025-08-04 08:12:22  Thành công
# 4    2023-08-02 20:52:30  Thành công
# ..                   ...         ...
# 995  2024-07-28 01:50:36  Thành công
# 996  2023-03-21 19:11:48  Thành công
# 997  2024-10-02 19:30:15  Thành công
# 998  2023-07-20 20:42:47  Thành công
# 999  2024-06-19 00:53:03  Thành công
#
# [1000 rows x 24 columns]
