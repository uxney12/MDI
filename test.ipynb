# %%
import pyarrow.parquet as pq

dataset = pq.ParquetDataset(r"E:\MH\VehicleApp\MDI\mpass.parquet")
table = dataset.read() 
df = table.to_pandas()

# %%
df
# Out:
#         _operation               _processed_at        _record_id  \
# 0     INITIAL_LOAD  2025-10-22T04:55:34.424475     Mpass_mpass_1
# 1     INITIAL_LOAD  2025-10-22T04:55:34.427213     Mpass_mpass_2
# 2     INITIAL_LOAD  2025-10-22T04:55:34.429194     Mpass_mpass_3
# 3     INITIAL_LOAD  2025-10-22T04:55:34.430879     Mpass_mpass_4
# 4     INITIAL_LOAD  2025-10-22T04:55:34.432536     Mpass_mpass_5
# ...            ...                         ...               ...
# 996   INITIAL_LOAD  2025-10-22T04:55:35.875095   Mpass_mpass_997
# 997   INITIAL_LOAD  2025-10-22T04:55:35.876449   Mpass_mpass_998
# 998   INITIAL_LOAD  2025-10-22T04:55:35.877756   Mpass_mpass_999
# 999   INITIAL_LOAD  2025-10-22T04:55:35.879032  Mpass_mpass_1000
# 1000        DELETE  2025-10-22T04:56:14.560576  Mpass_mpass_1001
#
#      _source_database _source_table _source_type deleted id_cuoc_xe  \
# 0               Mpass         mpass        mssql   False   CX671724
# ...

# %%
# Cách 1: dùng .shape
num_rows = df_filtered.shape[0]

# Cách 2: dùng len()
num_rows = len(df_filtered)

print("Số dòng:", num_rows)
# Out:
# Số dòng: 1002
